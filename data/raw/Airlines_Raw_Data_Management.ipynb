# %%
# %pip install pandas 

import os
import pandas as pd

def split_csv_in_subfolders(root_dir, chunk_size_mb=25):
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith(".csv"):
                file_path = os.path.join(subdir, file)
                file_size = os.path.getsize(file_path) / (1024 * 1024)  # Convert to MB
                
                if file_size > chunk_size_mb:
                    print(f"Splitting {file_path} ({file_size:.2f} MB)")
                    
                    # Read CSV with error handling
                    try:
                        df = pd.read_csv(file_path, low_memory=False, on_bad_lines='skip')
                    except Exception as e:
                        print(f"Error reading {file_path}: {e}")
                        continue
                    
                    num_chunks = int(file_size // chunk_size_mb) + 1
                    chunk_size = len(df) // num_chunks
                    
                    for i in range(num_chunks):
                        start_idx = i * chunk_size
                        end_idx = (i + 1) * chunk_size if i < num_chunks - 1 else len(df)
                        chunk_df = df.iloc[start_idx:end_idx]
                        chunk_file = os.path.join(subdir, f"{file}_chunk_{i}.csv")
                        chunk_df.to_csv(chunk_file, index=False)
                        print(f"Saved {chunk_file} ({os.path.getsize(chunk_file) / (1024 * 1024):.2f} MB)")
                    
                    os.remove(file_path)  # Remove original file after splitting
                    print(f"Original file {file_path} removed.")

def merge_csv_in_subfolders(root_dir):
    for subdir, _, files in os.walk(root_dir):
        chunk_files = sorted([os.path.join(subdir, f) for f in files if "_chunk_" in f and f.endswith(".csv")])
        if chunk_files:
            merged_filename = chunk_files[0].rsplit("_chunk_", 1)[0]  # Remove chunk suffix
            df_list = []
            
            for chunk in chunk_files:
                try:
                    df_list.append(pd.read_csv(chunk, low_memory=False, on_bad_lines='skip'))
                except Exception as e:
                    print(f"Error reading {chunk}: {e}")
                    continue
            
            if df_list:
                merged_df = pd.concat(df_list, ignore_index=True)
                merged_df.to_csv(merged_filename, index=False)
                print(f"Merged file saved as {merged_filename}")
                
                for chunk_file in chunk_files:
                    os.remove(chunk_file)
                print("Chunk files removed.")
                
 # Example Usage
root_directory = "airlines_raw"
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Split large CSV files in subfolders
split_csv_in_subfolders(root_directory)
# Out:
# Splitting airlines_raw/hu-chh/hu-chh_aircraft_data.csv (58.71 MB)
# Saved airlines_raw/hu-chh/hu-chh_aircraft_data.csv_chunk_0.csv (19.08 MB)
# Saved airlines_raw/hu-chh/hu-chh_aircraft_data.csv_chunk_1.csv (19.73 MB)
# Saved airlines_raw/hu-chh/hu-chh_aircraft_data.csv_chunk_2.csv (19.89 MB)
# Original file airlines_raw/hu-chh/hu-chh_aircraft_data.csv removed.
# Splitting airlines_raw/6e-igo/6e-igo_aircraft_data.csv (152.63 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_0.csv (22.00 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_1.csv (21.96 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_2.csv (21.95 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_3.csv (22.04 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_4.csv (21.94 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_5.csv (21.51 MB)
# Saved airlines_raw/6e-igo/6e-igo_aircraft_data.csv_chunk_6.csv (21.24 MB)
# Original file airlines_raw/6e-igo/6e-igo_aircraft_data.csv removed.
# Splitting airlines_raw/tk-thy/tk-thy_aircraft_data.csv (93.22 MB)
# Saved airlines_raw/tk-thy/tk-thy_aircraft_data.csv_chunk_0.csv (22.65 MB)
# Saved airlines_raw/tk-thy/tk-thy_aircraft_data.csv_chunk_1.csv (23.42 MB)
# Saved airlines_raw/tk-thy/tk-thy_aircraft_data.csv_chunk_2.csv (23.72 MB)
# Saved airlines_raw/tk-thy/tk-thy_aircraft_data.csv_chunk_3.csv (23.44 MB)
# Original file airlines_raw/tk-thy/tk-thy_aircraft_data.csv removed.
# Splitting airlines_raw/ba-baw/ba-baw_aircraft_data.csv (29.03 MB)
# Saved airlines_raw/ba-baw/ba-baw_aircraft_data.csv_chunk_0.csv (14.37 MB)
# Saved airlines_raw/ba-baw/ba-baw_aircraft_data.csv_chunk_1.csv (14.67 MB)
# Original file airlines_raw/ba-baw/ba-baw_aircraft_data.csv removed.
# Splitting airlines_raw/id-btk/id-btk_aircraft_data.csv (29.47 MB)
# Saved airlines_raw/id-btk/id-btk_aircraft_data.csv_chunk_0.csv (14.45 MB)
# Saved airlines_raw/id-btk/id-btk_aircraft_data.csv_chunk_1.csv (15.02 MB)
# Original file airlines_raw/id-btk/id-btk_aircraft_data.csv removed.
# Splitting airlines_raw/ua-ual/ua-ual_aircraft_data.csv (149.68 MB)
# Saved airlines_raw/ua-ual/ua-ual_aircraft_data.csv_chunk_0.csv (24.77 MB)
# Saved airlines_raw/ua-ual/ua-ual_aircraft_data.csv_chunk_1.csv (24.78 MB)
# Saved airlines_raw/ua-ual/ua-ual_aircraft_data.csv_chunk_2.csv (25.11 MB)
# Saved airlines_raw/ua-ual/ua-ual_aircraft_data.csv_chunk_3.csv (25.03 MB)
# Saved airlines_raw/ua-ual/ua-ual_aircraft_data.csv_chunk_4.csv (25.02 MB)
# Saved airlines_raw/ua-ual/ua-ual_aircraft_data.csv_chunk_5.csv (24.97 MB)
# Original file airlines_raw/ua-ual/ua-ual_aircraft_data.csv removed.
# Splitting airlines_raw/gs-gcr/gs-gcr_aircraft_data.csv (25.25 MB)
# Saved airlines_raw/gs-gcr/gs-gcr_aircraft_data.csv_chunk_0.csv (12.66 MB)
# Saved airlines_raw/gs-gcr/gs-gcr_aircraft_data.csv_chunk_1.csv (12.59 MB)
# Original file airlines_raw/gs-gcr/gs-gcr_aircraft_data.csv removed.
# Splitting airlines_raw/qr-qtr/qr-qtr_aircraft_data.csv (47.34 MB)
# Saved airlines_raw/qr-qtr/qr-qtr_aircraft_data.csv_chunk_0.csv (23.39 MB)
# Saved airlines_raw/qr-qtr/qr-qtr_aircraft_data.csv_chunk_1.csv (23.96 MB)
# Original file airlines_raw/qr-qtr/qr-qtr_aircraft_data.csv removed.
# Splitting airlines_raw/mf-cxa/mf-cxa_aircraft_data.csv (50.80 MB)
# Saved airlines_raw/mf-cxa/mf-cxa_aircraft_data.csv_chunk_0.csv (16.87 MB)
# Saved airlines_raw/mf-cxa/mf-cxa_aircraft_data.csv_chunk_1.csv (17.05 MB)
# Saved airlines_raw/mf-cxa/mf-cxa_aircraft_data.csv_chunk_2.csv (16.88 MB)
# Original file airlines_raw/mf-cxa/mf-cxa_aircraft_data.csv removed.
# Splitting airlines_raw/ek-uae/ek-uae_aircraft_data.csv (25.56 MB)
# Saved airlines_raw/ek-uae/ek-uae_aircraft_data.csv_chunk_0.csv (12.72 MB)
# Saved airlines_raw/ek-uae/ek-uae_aircraft_data.csv_chunk_1.csv (12.85 MB)
# Original file airlines_raw/ek-uae/ek-uae_aircraft_data.csv removed.
# Splitting airlines_raw/sc-cdg/sc-cdg_aircraft_data.csv (46.97 MB)
# Saved airlines_raw/sc-cdg/sc-cdg_aircraft_data.csv_chunk_0.csv (23.50 MB)
# Saved airlines_raw/sc-cdg/sc-cdg_aircraft_data.csv_chunk_1.csv (23.47 MB)
# Original file airlines_raw/sc-cdg/sc-cdg_aircraft_data.csv removed.
# Splitting airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv (82.95 MB)
# Saved airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv_chunk_0.csv (20.07 MB)
# Saved airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv_chunk_1.csv (20.56 MB)
# Saved airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv_chunk_2.csv (21.18 MB)
# Saved airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv_chunk_3.csv (21.14 MB)
# Original file airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv removed.
# Splitting airlines_raw/qf-qfa/qf-qfa_aircraft_data.csv (27.46 MB)
# Saved airlines_raw/qf-qfa/qf-qfa_aircraft_data.csv_chunk_0.csv (13.67 MB)
# Saved airlines_raw/qf-qfa/qf-qfa_aircraft_data.csv_chunk_1.csv (13.80 MB)
# Original file airlines_raw/qf-qfa/qf-qfa_aircraft_data.csv removed.
# Splitting airlines_raw/kl-klm/kl-klm_aircraft_data.csv (48.21 MB)
# Saved airlines_raw/kl-klm/kl-klm_aircraft_data.csv_chunk_0.csv (23.42 MB)
# Saved airlines_raw/kl-klm/kl-klm_aircraft_data.csv_chunk_1.csv (24.79 MB)
# Original file airlines_raw/kl-klm/kl-klm_aircraft_data.csv removed.
# Splitting airlines_raw/5j-ceb/5j-ceb_aircraft_data.csv (35.00 MB)
# Saved airlines_raw/5j-ceb/5j-ceb_aircraft_data.csv_chunk_0.csv (17.74 MB)
# Saved airlines_raw/5j-ceb/5j-ceb_aircraft_data.csv_chunk_1.csv (17.26 MB)
# Original file airlines_raw/5j-ceb/5j-ceb_aircraft_data.csv removed.
# Splitting airlines_raw/ai-aic/ai-aic_aircraft_data.csv (57.54 MB)
# Saved airlines_raw/ai-aic/ai-aic_aircraft_data.csv_chunk_0.csv (19.31 MB)
# Saved airlines_raw/ai-aic/ai-aic_aircraft_data.csv_chunk_1.csv (19.13 MB)
# Saved airlines_raw/ai-aic/ai-aic_aircraft_data.csv_chunk_2.csv (19.10 MB)
# Original file airlines_raw/ai-aic/ai-aic_aircraft_data.csv removed.
# Splitting airlines_raw/9c-cqh/9c-cqh_aircraft_data.csv (38.08 MB)
# Saved airlines_raw/9c-cqh/9c-cqh_aircraft_data.csv_chunk_0.csv (19.02 MB)
# Saved airlines_raw/9c-cqh/9c-cqh_aircraft_data.csv_chunk_1.csv (19.06 MB)
# Original file airlines_raw/9c-cqh/9c-cqh_aircraft_data.csv removed.
# Splitting airlines_raw/ca-cca/ca-cca_aircraft_data.csv (119.02 MB)
# Saved airlines_raw/ca-cca/ca-cca_aircraft_data.csv_chunk_0.csv (23.76 MB)
# Saved airlines_raw/ca-cca/ca-cca_aircraft_data.csv_chunk_1.csv (23.74 MB)
# Saved airlines_raw/ca-cca/ca-cca_aircraft_data.csv_chunk_2.csv (23.68 MB)
# Saved airlines_raw/ca-cca/ca-cca_aircraft_data.csv_chunk_3.csv (23.77 MB)
# Saved airlines_raw/ca-cca/ca-cca_aircraft_data.csv_chunk_4.csv (24.05 MB)
# Original file airlines_raw/ca-cca/ca-cca_aircraft_data.csv removed.
# Splitting airlines_raw/jq-jst/jq-jst_aircraft_data.csv (36.60 MB)
# Saved airlines_raw/jq-jst/jq-jst_aircraft_data.csv_chunk_0.csv (18.36 MB)
# Saved airlines_raw/jq-jst/jq-jst_aircraft_data.csv_chunk_1.csv (18.24 MB)
# Original file airlines_raw/jq-jst/jq-jst_aircraft_data.csv removed.
# Splitting airlines_raw/zh-csz/zh-csz_aircraft_data.csv (59.20 MB)
# Saved airlines_raw/zh-csz/zh-csz_aircraft_data.csv_chunk_0.csv (19.77 MB)
# Saved airlines_raw/zh-csz/zh-csz_aircraft_data.csv_chunk_1.csv (19.69 MB)
# Saved airlines_raw/zh-csz/zh-csz_aircraft_data.csv_chunk_2.csv (19.74 MB)
# Original file airlines_raw/zh-csz/zh-csz_aircraft_data.csv removed.
# Splitting airlines_raw/cz-csn/cz-csn_aircraft_data.csv (189.53 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_0.csv (23.72 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_1.csv (23.71 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_2.csv (23.62 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_3.csv (23.62 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_4.csv (23.95 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_5.csv (23.70 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_6.csv (23.65 MB)
# Saved airlines_raw/cz-csn/cz-csn_aircraft_data.csv_chunk_7.csv (23.58 MB)
# Original file airlines_raw/cz-csn/cz-csn_aircraft_data.csv removed.
# Splitting airlines_raw/sq-sia/sq-sia_aircraft_data.csv (27.95 MB)
# Saved airlines_raw/sq-sia/sq-sia_aircraft_data.csv_chunk_0.csv (13.80 MB)
# Saved airlines_raw/sq-sia/sq-sia_aircraft_data.csv_chunk_1.csv (14.15 MB)
# Original file airlines_raw/sq-sia/sq-sia_aircraft_data.csv removed.
# Splitting airlines_raw/3u-csc/3u-csc_aircraft_data.csv (53.72 MB)
# Saved airlines_raw/3u-csc/3u-csc_aircraft_data.csv_chunk_0.csv (17.79 MB)
# Saved airlines_raw/3u-csc/3u-csc_aircraft_data.csv_chunk_1.csv (17.81 MB)
# Saved airlines_raw/3u-csc/3u-csc_aircraft_data.csv_chunk_2.csv (18.13 MB)
# Original file airlines_raw/3u-csc/3u-csc_aircraft_data.csv removed.
# Splitting airlines_raw/vj-vjc/vj-vjc_aircraft_data.csv (38.45 MB)
# Saved airlines_raw/vj-vjc/vj-vjc_aircraft_data.csv_chunk_0.csv (19.16 MB)
# Saved airlines_raw/vj-vjc/vj-vjc_aircraft_data.csv_chunk_1.csv (19.29 MB)
# Original file airlines_raw/vj-vjc/vj-vjc_aircraft_data.csv removed.
# Splitting airlines_raw/ho-dkh/ho-dkh_aircraft_data.csv (29.81 MB)
# Saved airlines_raw/ho-dkh/ho-dkh_aircraft_data.csv_chunk_0.csv (14.77 MB)
# Saved airlines_raw/ho-dkh/ho-dkh_aircraft_data.csv_chunk_1.csv (15.04 MB)
# Original file airlines_raw/ho-dkh/ho-dkh_aircraft_data.csv removed.
# Splitting airlines_raw/ke-kal/ke-kal_aircraft_data.csv (31.48 MB)
# Saved airlines_raw/ke-kal/ke-kal_aircraft_data.csv_chunk_0.csv (15.54 MB)
# Saved airlines_raw/ke-kal/ke-kal_aircraft_data.csv_chunk_1.csv (15.94 MB)
# Original file airlines_raw/ke-kal/ke-kal_aircraft_data.csv removed.
# Splitting airlines_raw/mu-ces/mu-ces_aircraft_data.csv (200.69 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_0.csv (22.30 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_1.csv (22.30 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_2.csv (22.17 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_3.csv (22.29 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_4.csv (22.30 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_5.csv (22.34 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_6.csv (22.43 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_7.csv (22.30 MB)
# Saved airlines_raw/mu-ces/mu-ces_aircraft_data.csv_chunk_8.csv (22.27 MB)
# Original file airlines_raw/mu-ces/mu-ces_aircraft_data.csv removed.
# Splitting airlines_raw/sv-sva/sv-sva_aircraft_data.csv (40.63 MB)
# Saved airlines_raw/sv-sva/sv-sva_aircraft_data.csv_chunk_0.csv (20.13 MB)
# Saved airlines_raw/sv-sva/sv-sva_aircraft_data.csv_chunk_1.csv (20.50 MB)
# Original file airlines_raw/sv-sva/sv-sva_aircraft_data.csv removed.
# Splitting airlines_raw/ac-aca/ac-aca_aircraft_data.csv (75.99 MB)
# Saved airlines_raw/ac-aca/ac-aca_aircraft_data.csv_chunk_0.csv (18.24 MB)
# Saved airlines_raw/ac-aca/ac-aca_aircraft_data.csv_chunk_1.csv (18.48 MB)
# Saved airlines_raw/ac-aca/ac-aca_aircraft_data.csv_chunk_2.csv (19.31 MB)
# Saved airlines_raw/ac-aca/ac-aca_aircraft_data.csv_chunk_3.csv (19.96 MB)
# Original file airlines_raw/ac-aca/ac-aca_aircraft_data.csv removed.
# Splitting airlines_raw/vn-hvn/vn-hvn_aircraft_data.csv (29.20 MB)
# Saved airlines_raw/vn-hvn/vn-hvn_aircraft_data.csv_chunk_0.csv (14.33 MB)
# Saved airlines_raw/vn-hvn/vn-hvn_aircraft_data.csv_chunk_1.csv (14.87 MB)
# Original file airlines_raw/vn-hvn/vn-hvn_aircraft_data.csv removed.
# Splitting airlines_raw/jl-jal/jl-jal_aircraft_data.csv (42.46 MB)
# Saved airlines_raw/jl-jal/jl-jal_aircraft_data.csv_chunk_0.csv (20.99 MB)
# Saved airlines_raw/jl-jal/jl-jal_aircraft_data.csv_chunk_1.csv (21.47 MB)
# Original file airlines_raw/jl-jal/jl-jal_aircraft_data.csv removed.

# %%
# Merge split CSV files back in subfolders
merge_csv_in_subfolders(root_directory)
# Out:
# Merged file saved as airlines_raw/hu-chh/hu-chh_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/6e-igo/6e-igo_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/tk-thy/tk-thy_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ba-baw/ba-baw_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/id-btk/id-btk_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ua-ual/ua-ual_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/gs-gcr/gs-gcr_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/qr-qtr/qr-qtr_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/mf-cxa/mf-cxa_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ek-uae/ek-uae_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/sc-cdg/sc-cdg_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/lh-dlh/lh-dlh_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/qf-qfa/qf-qfa_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/kl-klm/kl-klm_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/5j-ceb/5j-ceb_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ai-aic/ai-aic_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/9c-cqh/9c-cqh_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ca-cca/ca-cca_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/jq-jst/jq-jst_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/zh-csz/zh-csz_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/cz-csn/cz-csn_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/sq-sia/sq-sia_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/3u-csc/3u-csc_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/vj-vjc/vj-vjc_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ho-dkh/ho-dkh_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ke-kal/ke-kal_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/mu-ces/mu-ces_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/sv-sva/sv-sva_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/ac-aca/ac-aca_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/vn-hvn/vn-hvn_aircraft_data.csv
# Chunk files removed.
# Merged file saved as airlines_raw/jl-jal/jl-jal_aircraft_data.csv
# Chunk files removed.
